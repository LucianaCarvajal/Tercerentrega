# %% [markdown]
# # EDA INICIAL

# %%
# Se importan las librerías:panda y numpy
import pandas as pd
import numpy as np

# %%
## Se verifica el working directory
# %pwd
# Out:
# 'C:\\Users\\Usuario\\Desktop\\data science\\GRUPO 9 FINAL'

# %%
# Se importa el dataset (CSV) en una variable llamada amazon usando pandas.   
amazon=pd.read_csv(r'amazon_prime_titles.csv')

# %%
# Se visualiza el dataframe
amazon
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# ...                                                 ...             ...
# 9663                           Leo Gorcey, Bobby Jordan             NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...             NaN
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...             NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...             NaN
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...             NaN
#
#           date_added  release_year rating   duration                listed_in  \
# 0     March 30, 2021          2014    NaN    113 min            Comedy, Drama
# 1     March 30, 2021          2018    13+    110 min     Drama, International
# 2     March 30, 2021          2017    NaN     74 min  Action, Drama, Suspense
# 3     March 30, 2021          2014    NaN     69 min              Documentary
# 4     March 30, 2021          1989    NaN     45 min           Drama, Fantasy
# ...              ...           ...    ...        ...                      ...
# 9663             NaN          1940     7+     60 min                   Comedy
# 9664             NaN          2018    13+  4 Seasons                 TV Shows
# 9665             NaN          2008      R     90 min                   Action
# 9666             NaN          2021  TV-MA   1 Season            Drama, Sports
# 9667             NaN          2010      R    103 min  Action, Drama, Suspense
#
#                                             description
# 0     A small fishing village must procure a local d...
# 1     A Metro Family decides to fight a Cyber Crimin...
# 2     After a man discovers his wife is cheating on ...
# 3     Pink breaks the mold once again, bringing her ...
# 4     Teenage Matt Banting wants to work with a famo...
# ...                                                 ...
# 9663  New York City street principles get an East Si...
# 9664  This is Earth, 2100AD - and these are the adve...
# 9665  In war-torn Eastern Europe, a world-weary grou...
# 9666  The series tells the story of Diego Maradona, ...
# 9667  Harry Brown, starring two-time Academy Award w...
#
# [9668 rows x 12 columns]

# %%
# Se observa la cantidad de filas y columnas del dataframe
forma = amazon.shape
f"El dataset tiene {forma[0]} filas y {forma[1]} columnas"
# Out:
# 'El dataset tiene 9668 filas y 12 columnas'

# %%
# Se indaga sobre el tipo de estructura de datos que tiene el data frame.
type(amazon)
# Out:
# pandas.core.frame.DataFrame

# %%
# Se verifican si hay filas duplicadas
dupl = amazon.duplicated()
print(dupl.value_counts())
# Out:
# False    9668
# dtype: int64

# %% [markdown]
# No hay filas duplicadas.

# %% [markdown]
# ## Exploración de las columnas

# %%
#Se observan los nombres de las columnas
print(amazon.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Se observa el tipo de dato de cada columna:
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %%
# Se observan las primeras filas del dataset
amazon.head(10)
# Out:
#   show_id   type                  title                     director  \
# 0      s1  Movie    The Grand Seduction                 Don McKellar
# 1      s2  Movie   Take Care Good Night                 Girish Joshi
# 2      s3  Movie   Secrets of Deception                  Josh Webber
# 3      s4  Movie     Pink: Staying True               Sonia Anderson
# 4      s5  Movie          Monster Maker                 Giles Foster
# 5      s6  Movie  Living With Dinosaurs                 Paul Weiland
# 6      s7  Movie              Hired Gun                  Fran Strine
# 7      s8  Movie           Grease Live!  Thomas Kail, Alex Rudzinski
# 8      s9  Movie        Global Meltdown                Daniel Gilboy
# 9     s10  Movie         David's Mother        Robert Allan Ackerman
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# 5  Gregory Chisholm, Juliet Stevenson, Brian Hens...  United Kingdom
# 6  Alice Cooper, Liberty DeVitto, Ray Parker Jr.,...   United States
# 7  Julianne Hough, Aaron Tveit, Vanessa Hudgens, ...   United States
# 8  Michael Paré, Leanne Khol Young, Patrick J. Ma...          Canada
# 9    Kirstie Alley, Sam Waterston, Stockard Channing   United States
#
#        date_added  release_year rating duration  \
# 0  March 30, 2021          2014    NaN  113 min
# 1  March 30, 2021          2018    13+  110 min
# 2  March 30, 2021          2017    NaN   74 min
# 3  March 30, 2021          2014    NaN   69 min
# 4  March 30, 2021          1989    NaN   45 min
# 5  March 30, 2021          1989    NaN   52 min
# 6  March 30, 2021          2017    NaN   98 min
# 7  March 30, 2021          2016    NaN  131 min
# 8  March 30, 2021          2017    NaN   87 min
# 9   April 1, 2021          1994    NaN   92 min
#
#                            listed_in  \
# 0                      Comedy, Drama
# 1               Drama, International
# 2            Action, Drama, Suspense
# 3                        Documentary
# 4                     Drama, Fantasy
# 5                      Fantasy, Kids
# 6      Documentary, Special Interest
# 7                             Comedy
# 8  Action, Science Fiction, Suspense
# 9                              Drama
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...
# 3  Pink breaks the mold once again, bringing her ...
# 4  Teenage Matt Banting wants to work with a famo...
# 5  The story unfolds in a an English seaside town...
# 6  They are the "First Call, A-list" musicians, j...
# 7  This honest, uncompromising comedy chronicles ...
# 8  A helicopter pilot and an environmental scient...
# 9  Sally Goodson is a devoted mother to her autis...

# %% [raw]
# # Se inspeccionan las últimas filas del dataframe
# amazon.tail(10)

# %%
# Se consultan las estadísticas que describen al valor númerico del dataframe, que es release_year
amazon.describe()
# Out:
#        release_year
# count   9668.000000
# mean    2008.341849
# std       18.922482
# min     1920.000000
# 25%     2007.000000
# 50%     2016.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# ## Análisis de datos faltantes

# %%
# Se observan cuántos valores faltantes tiene cada columna:
missing_values = amazon.isnull().sum().sort_values(ascending = False) # contabiliza
        # datos faltantes ordenados de mayor a menor
        # según la columna
missing_values
# Out:
# date_added      9513
# country         8996
# director        2082
# cast            1233
# rating           337
# show_id            0
# type               0
# title              0
# release_year       0
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# visualización de valores faltantes
plt.figure(figsize=(10, 6))
sns.heatmap(amazon.isnull(), cmap='viridis', cbar=False)
plt.title('Valores Faltantes en el DataFrame')
plt.show()

# %% [markdown]
# Se pueden observar que en la columna fecha_agregada faltan todos datos. Lo mismo ocurre, con la columna país. Como no van a ser objeto de estudio de este análisis, no se  tendrá en cuenta su tratamiento. </br>
# Las columnas más importantes para el sistema de recomendación (título, descripcion, calificacion, elenco, listado_en) no tienen datos faltantes, por lo se trabajará con ellas sin dificultad.

# %% [markdown]
# ### ¿Cuántas películas y cuántas series hay en la plataforma?

# %%
# Se contabilizan la cantidad de filas de acuerdo a su tipo: películas o series. 
contar_tipo = amazon['type'].value_counts()
print(f"Hay {contar_tipo[0]} películas y {contar_tipo[1]} series")
# Out:
# Hay 7814 películas y 1854 series

# %%
# Se visualizan la cantidad de películas y tv show a travéz de un gráfico de barras

plt.bar(contar_tipo.index, contar_tipo.values)
plt.xlabel('Tipo', fontsize=18)
plt.ylabel('Cantidad de títulos', fontsize=15)
plt.title( 'Películas y series en amazon', fontsize=20)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Columna calificación

# %%
# Se contabilizan la cantidad de filas para cada calificacion
contar_calif = amazon['rating'].value_counts()
print(contar_calif)
# Out:
# 13+         2117
# 16+         1547
# ALL         1268
# 18+         1243
# R           1010
# PG-13        393
# 7+           385
# PG           253
# NR           223
# TV-14        208
# TV-PG        169
# TV-NR        105
# G             93
# TV-G          81
# TV-MA         77
# TV-Y          74
# TV-Y7         39
# UNRATED       33
# NC-17          3
# AGES_18_       3
# NOT_RATE       3
# AGES_16_       2
# 16             1
# ALL_AGES       1
# Name: rating, dtype: int64

# %% [markdown]
# Dado que las calificaciones para TV y cine son distintas, se graficaran por separado.

# %%
# Se creará un nuevo dataframe filtrando por el valor de la columna tipo (película)
amazon_peli = amazon[amazon['type'] == "Movie"]
amazon_peli.shape ## Se verifica la cantidad de filas
# Out:
# (7814, 12)

# %%
# Se creará un nuevo dataframe filtrando por el valor de la columna tipo (tv show)
amazon_tv = amazon[amazon['type'] == "TV Show"]
amazon_tv.shape ## Se verifica la cantidad de filas
# Out:
# (1854, 12)

# %%
# Se cuenta la cantidad de filasa a travpés de un gráfico de barras
contar_calif_peli = amazon_peli['rating'].value_counts()

# Crear el gráfico de barras
plt.bar(contar_calif_peli.index, contar_calif_peli.values)
plt.xlabel('Calificación', fontsize=15)
plt.ylabel('Cantidad de títulos', fontsize=15)
plt.title('Películas por cada calificación en amazon', fontsize=20)
plt.xticks(rotation=45, fontsize=8)
plt.yticks(fontsize=13)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# *****  Habría que limpiar los valores de calificación, ya que vemos que las categorías con menor frecuencia son repeticiones de las de mayor frecuencia.
# Pero vamos a seguir adelante.****ver esta nota

# %%
# Se contabiliza la cantidad de filas 
contar_calif_tv = amazon_tv['rating'].value_counts()

# Crear el gráfico de barras
plt.bar(contar_calif_tv.index, contar_calif_tv.values)
plt.xlabel('Calificación', fontsize=15)
plt.ylabel('Cantidad de títulos', fontsize=15)
plt.title('Series por calificación en amazon', fontsize=18)
plt.xticks(rotation=45, fontsize=9)
plt.yticks(fontsize=13)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Se guardan los dataframe en archivos CSV
amazon_peli.to_csv(r'amazon_peli.csv', index=False)
amazon_tv.to_csv(r'amazon_tv.csv', index=False)

# %% [markdown]
# ## Columna duracion

# %%
# Se observa la columna duracion para las películas
amazon_peli.head(3)
# Out:
#   show_id   type                 title      director  \
# 0      s1  Movie   The Grand Seduction  Don McKellar
# 1      s2  Movie  Take Care Good Night  Girish Joshi
# 2      s3  Movie  Secrets of Deception   Josh Webber
#
#                                                 cast        country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...  United States
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...

# %%
# Se observa la columna duracion para las series
amazon_tv.head(3)
# Out:
#    show_id     type                          title director  \
# 17     s18  TV Show                     Zoo Babies      NaN
# 18     s19  TV Show  Zoë Coombs Marr: Bossy Bottom      NaN
# 20     s21  TV Show                     Zoboomafoo      NaN
#
#                           cast country date_added  release_year rating  \
# 17  Narrator - Gillian Barlett     NaN        NaN          2008    ALL
# 18             Zoë Coombs Marr     NaN        NaN          2020    18+
# 20                         NaN     NaN        NaN          2001   TV-Y
#
#     duration                      listed_in  \
# 17  1 Season         Kids, Special Interest
# 18  1 Season  Comedy, Talk Show and Variety
# 20  1 Season                           Kids
#
#                                           description
# 17  A heart warming and inspiring series that welc...
# 18  Zoë Coombs Marr has been on hiatus. Sort of. F...
# 20  Chris and Martin Kratt bring their enthusiasm ...

# %% [markdown]
# Se observa que para las películas, la duracion se expresa con la unidad minutos.Mientras que para las series, se expresa con la unidad temporadas.
# Esto significa que solamente se utilizará esta columna para clasificar por separado series o películas, ya que poseen distintas unidades de medida (minutos y temporadas respectivamente).
# Se procesarán los datos de la columna para utilizarlos.

# %%
# Se importan los dataframe (CSV) creados, usando pandas.  
amazon_peli = pd.read_csv(r'amazon_peli.csv')
amazon_tv = pd.read_csv(r'amazon_tv.csv')

# %%
# Se quitan "min" y se trasnforma el tipo de dato númerico entero: integer 
amazon_peli['duration'] = amazon_peli['duration'].str.replace(' min', '').astype(int)

# %%
# Con las series se obtienen los valores unicos en la columna duracion para las series 
uniquedur = amazon_tv['duration'].unique()
print(uniquedur)
# Out:
# ['1 Season' '3 Seasons' '2 Seasons' '4 Seasons' '7 Seasons' '9 Seasons'
#  '6 Seasons' '5 Seasons' '29 Seasons' '19 Seasons' '21 Seasons'
#  '8 Seasons' '12 Seasons' '11 Seasons' '10 Seasons' '14 Seasons'
#  '15 Seasons']

# %% [markdown]
# Se observa que hay algunas filas con el formato "numero + season/seasons" y otras con el formato "numero + s". </br>
# Asíque algunas son temporadas y otras segundos. </br>
# Por el momento se reemplazan las que estén en temporadas.

# %%
# Se quitan "Season" y "Seasons"
amazon_tv['duration'] = amazon_tv['duration'].str.replace(' Season', '').str.replace(' Seasons', '')

# %% [markdown]
# No se puede convertir a integer porque algunas filas están en temporadass y no fueron modificadas, así que al convertir a integer se volverían nulas.
# Por ahora se continuará la exploración adelante aunque queda pendiente el procesamiento de esta columna.
# Según cómo querramos utilizar las distintas formas de duración, quizás deberíamos crear distintas columnas para cada forma de medición, y explorar por qué algunos productos se miden en segundos (qué tipo de productos son? nos sirven para el análisis? deberíamos eliminarlos?).

# %% [markdown]
# ### ¿Cuántas series y películas de cada año hay en la plataforma?

# %%
# Agrupar por tipo y anio, y contar la cantidad de filas
contar_anio = amazon.groupby(['release_year', 'type']).size().unstack()

# Crear un gráfico de barras apiladas con anio en el eje x
plt.figure(figsize=(10, 6))
contar_anio.plot(kind='bar', stacked=True)
plt.xlabel('Año', fontsize = 15)
plt.ylabel('Cantidad de Títulos', fontsize = 15)
plt.title('Series y películas por año', fontsize = 20)
plt.legend(title='Tipo', fontsize = 15)
plt.xticks([]) # eliminar etiquetas de eje x porque queda muy cargado
plt.yticks(fontsize = 15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Columna listado_en: categorías y géneros

# %%
amazon['listed_in'].head(3)
# Out:
# 0              Comedy, Drama
# 1       Drama, International
# 2    Action, Drama, Suspense
# Name: listed_in, dtype: object

# %% [markdown]
# Se observa que la columna listado_en contiene diversos valores separados por comas. Se separa cada valor en una columna para poder utilizarlas para agrupar las filas.

# %%
# Dividir los valores en columnas separadas
generos = amazon['listed_in'].str.split(',', expand=True)
print(generos)
# Out:
#                 0               1          2     3     4
# 0          Comedy           Drama       None  None  None
# 1           Drama   International       None  None  None
# 2          Action           Drama   Suspense  None  None
# 3     Documentary            None       None  None  None
# 4           Drama         Fantasy       None  None  None
# ...           ...             ...        ...   ...   ...
# 9663       Comedy            None       None  None  None
# 9664     TV Shows            None       None  None  None
# 9665       Action            None       None  None  None
# 9666        Drama          Sports       None  None  None
# 9667       Action           Drama   Suspense  None  None
#
# [9668 rows x 5 columns]

# %%
generos.columns = ['gen1', 'gen2', 'gen3', 'gen4', 'gen5']

# %%
print(generos)
# Out:
#              gen1            gen2       gen3  gen4  gen5
# 0          Comedy           Drama       None  None  None
# 1           Drama   International       None  None  None
# 2          Action           Drama   Suspense  None  None
# 3     Documentary            None       None  None  None
# 4           Drama         Fantasy       None  None  None
# ...           ...             ...        ...   ...   ...
# 9663       Comedy            None       None  None  None
# 9664     TV Shows            None       None  None  None
# 9665       Action            None       None  None  None
# 9666        Drama          Sports       None  None  None
# 9667       Action           Drama   Suspense  None  None
#
# [9668 rows x 5 columns]

# %%
# Concatenar las nuevas columnas al DataFrame original
amazon = pd.concat([amazon, generos], axis=1)
print(amazon)
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# ...                                                 ...             ...
# 9663                           Leo Gorcey, Bobby Jordan             NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...             NaN
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...             NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...             NaN
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...             NaN
#
#           date_added  release_year rating   duration                listed_in  \
# 0     March 30, 2021          2014    NaN    113 min            Comedy, Drama
# 1     March 30, 2021          2018    13+    110 min     Drama, International
# 2     March 30, 2021          2017    NaN     74 min  Action, Drama, Suspense
# 3     March 30, 2021          2014    NaN     69 min              Documentary
# 4     March 30, 2021          1989    NaN     45 min           Drama, Fantasy
# ...              ...           ...    ...        ...                      ...
# 9663             NaN          1940     7+     60 min                   Comedy
# 9664             NaN          2018    13+  4 Seasons                 TV Shows
# 9665             NaN          2008      R     90 min                   Action
# 9666             NaN          2021  TV-MA   1 Season            Drama, Sports
# 9667             NaN          2010      R    103 min  Action, Drama, Suspense
#
#                                             description         gen1  \
# 0     A small fishing village must procure a local d...       Comedy
# 1     A Metro Family decides to fight a Cyber Crimin...        Drama
# 2     After a man discovers his wife is cheating on ...       Action
# 3     Pink breaks the mold once again, bringing her ...  Documentary
# 4     Teenage Matt Banting wants to work with a famo...        Drama
# ...                                                 ...          ...
# 9663  New York City street principles get an East Si...       Comedy
# 9664  This is Earth, 2100AD - and these are the adve...     TV Shows
# 9665  In war-torn Eastern Europe, a world-weary grou...       Action
# 9666  The series tells the story of Diego Maradona, ...        Drama
# 9667  Harry Brown, starring two-time Academy Award w...       Action
#
#                 gen2       gen3  gen4  gen5
# 0              Drama       None  None  None
# 1      International       None  None  None
# 2              Drama   Suspense  None  None
# 3               None       None  None  None
# 4            Fantasy       None  None  None
# ...              ...        ...   ...   ...
# 9663            None       None  None  None
# 9664            None       None  None  None
# 9665            None       None  None  None
# 9666          Sports       None  None  None
# 9667           Drama   Suspense  None  None
#
# [9668 rows x 17 columns]

# %% [markdown]
# ****No pude procesar esta columna de manera que me permita agrupar y graficar por género/categoría. Un camino posible sería crear columnas dummies para cada categoría, tal que cada fila contenga 1 o 0 según corresponda. Pero quizás hay una forma más elegante ya que serían muchas columnas dummies. ***ver nota

# %% [markdown]
# Se continua con la exploración

# %%
# Contar la cantidad de filas para cada valor único en gen1
contar_gen1 = amazon['gen1'].value_counts()

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(contar_gen1.index, contar_gen1.values)
plt.xlabel('Valores en columna A')
plt.ylabel('Cantidad de filas')
plt.title('Distribución de valores en columna A')
plt.xticks(rotation=80, fontsize=7)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Obtener los valores únicos en la columna
uniquegen1 = amazon['gen1'].unique()
print(uniquegen1)
# Out:
# ['Comedy' 'Drama' 'Action' 'Documentary' 'Fantasy' 'Adventure' 'Horror'
#  'Kids' 'Science Fiction' 'Arts' 'TV Shows' 'Animation' 'Anime'
#  'Music Videos and Concerts' 'Fitness' 'Faith and Spirituality'
#  'Special Interest' 'Suspense' 'Unscripted' 'Western' 'Arthouse' 'Sports'
#  'Military and War' 'International' 'Romance' 'Young Adult Audience'
#  'Talk Show and Variety' 'LGBTQ' 'Historical']

# %%
# Obtener los valores únicos en la columna
uniquegen2 = amazon['gen2'].unique()
print(uniquegen2)
# Out:
# [' Drama' ' International' None ' Fantasy' ' Kids' ' Special Interest'
#  ' Science Fiction' ' Suspense' ' Sports' ' Talk Show and Variety'
#  ' Anime' ' Entertainment' ' Adventure' ' Military and War' ' Western'
#  ' Animation' ' LGBTQ' ' Romance' ' Documentary' ' Faith and Spirituality'
#  ' Young Adult Audience' ' Comedy' ' Horror' ' Music Videos and Concerts'
#  ' Unscripted' ' Historical' ' Arts' ' Arthouse']

# %%
# Obtener los valores únicos en la columna
uniquegen3 = amazon['gen3'].unique()
print(uniquegen3)
# Out:
# [None ' Suspense' ' Comedy' ' and Culture' ' Fantasy' ' Animation'
#  ' Western' ' Kids' ' Unscripted' ' Sports' ' Special Interest' ' Drama'
#  ' International' ' Anime' ' LGBTQ' ' Romance' ' Young Adult Audience'
#  ' Horror' ' Science Fiction' ' Faith and Spirituality' ' Historical'
#  ' Military and War' ' Entertainment' ' Documentary'
#  ' Talk Show and Variety' ' Arts' ' Music Videos and Concerts']

# %%
# Obtener los valores únicos en la columna
uniquegen4 = amazon['gen4'].unique()
print(uniquegen4)
# Out:
# [None ' Comedy' ' Documentary' ' Drama' ' and Culture'
#  ' Music Videos and Concerts' ' Entertainment' ' International' ' Romance'
#  ' Horror' ' Fantasy' ' LGBTQ' ' Kids' ' Special Interest'
#  ' Young Adult Audience']

# %%
# Obtener los valores únicos en la columna
uniquegen5 = amazon['gen5'].unique()
print(uniquegen5)
# Out:
# [None ' Drama' ' Talk Show and Variety' ' Special Interest'
#  ' Music Videos and Concerts' ' Romance' ' Comedy' ' Documentary'
#  ' Military and War' ' Western' ' Kids' ' International' ' and Culture'
#  ' Unscripted' ' LGBTQ' ' Young Adult Audience' ' Science Fiction'
#  ' Suspense' ' Horror' ' Faith and Spirituality']

# %%
# Se importan el resto de data set a emplear
netflix=pd.read_csv(r'netflix_titles.csv')

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
# Se crea un nuevo dataframe que contenga sólo películas
netflix_peli = netflix[netflix['type'] == "Movie"]
netflix_peli.shape # Se verifica la cantidad de filas
# Out:
# (6131, 12)

# %%
# Se guarda el dataframe en archivo CSV
netflix_peli.to_csv(r'C:\\Users\\Usuario\\Desktop\\data science\\GRUPO 9 FINAL\netflix_peli.csv', index=False)

# %%
# Se importa el dataframe creado 
netflix_peli = pd.read_csv(r'netflix_peli.csv')
netflix_peli
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 1         s7  Movie  My Little Pony: A New Generation
# 2         s8  Movie                           Sankofa
# 3        s10  Movie                      The Starling
# 4        s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 6126   s8802  Movie                           Zinzana
# 6127   s8803  Movie                            Zodiac
# 6128   s8805  Movie                        Zombieland
# 6129   s8806  Movie                              Zoom
# 6130   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 1     Robert Cullen, José Luis Ucha
# 2                      Haile Gerima
# 3                    Theodore Melfi
# 4               Christian Schwochow
# ...                             ...
# 6126                Majid Al Ansari
# 6127                  David Fincher
# 6128                Ruben Fleischer
# 6129                   Peter Hewitt
# 6130                    Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# 1     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 2     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 3     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 4     Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                 ...
# 6126  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 6127  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 6128  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 6129  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 6130  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country          date_added  \
# 0                                         United States  September 25, 2021
# 1                                                   NaN  September 24, 2021
# 2     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 3                                         United States  September 24, 2021
# 4                               Germany, Czech Republic  September 23, 2021
# ...                                                 ...                 ...
# 6126                       United Arab Emirates, Jordan       March 9, 2016
# 6127                                      United States   November 20, 2019
# 6128                                      United States    November 1, 2019
# 6129                                      United States    January 11, 2020
# 6130                                              India       March 2, 2019
#
#       release_year rating duration  \
# 0             2020  PG-13   90 min
# 1             2021     PG   91 min
# 2             1993  TV-MA  125 min
# 3             2021  PG-13  104 min
# 4             2021  TV-MA  127 min
# ...            ...    ...      ...
# 6126          2015  TV-MA   96 min
# 6127          2007      R  158 min
# 6128          2009      R   88 min
# 6129          2006     PG   88 min
# 6130          2015  TV-14  111 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 1                             Children & Family Movies
# 2     Dramas, Independent Movies, International Movies
# 3                                     Comedies, Dramas
# 4                         Dramas, International Movies
# ...                                                ...
# 6126           Dramas, International Movies, Thrillers
# 6127                    Cult Movies, Dramas, Thrillers
# 6128                           Comedies, Horror Movies
# 6129                Children & Family Movies, Comedies
# 6130    Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     Equestria's divided. But a bright-eyed hero be...
# 2     On a photo shoot in Ghana, an American model s...
# 3     A woman adjusting to life after a loss contend...
# 4     After most of her family is murdered in a terr...
# ...                                                 ...
# 6126  Recovering alcoholic Talal wakes up inside a s...
# 6127  A political cartoonist, a crime reporter and a...
# 6128  Looking to survive in a world taken over by zo...
# 6129  Dragged from civilian life, a former superhero...
# 6130  A scrappy but poor boy worms his way into a ty...
#
# [6131 rows x 12 columns]

# %%
# Se crea la columna plataforma 
netflix_peli['plataforma']='netflix'
netflix_peli
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 1         s7  Movie  My Little Pony: A New Generation
# 2         s8  Movie                           Sankofa
# 3        s10  Movie                      The Starling
# 4        s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 6126   s8802  Movie                           Zinzana
# 6127   s8803  Movie                            Zodiac
# 6128   s8805  Movie                        Zombieland
# 6129   s8806  Movie                              Zoom
# 6130   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 1     Robert Cullen, José Luis Ucha
# 2                      Haile Gerima
# 3                    Theodore Melfi
# 4               Christian Schwochow
# ...                             ...
# 6126                Majid Al Ansari
# 6127                  David Fincher
# 6128                Ruben Fleischer
# 6129                   Peter Hewitt
# 6130                    Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# 1     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 2     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 3     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 4     Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                 ...
# 6126  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 6127  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 6128  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 6129  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 6130  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country          date_added  \
# 0                                         United States  September 25, 2021
# 1                                                   NaN  September 24, 2021
# 2     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 3                                         United States  September 24, 2021
# 4                               Germany, Czech Republic  September 23, 2021
# ...                                                 ...                 ...
# 6126                       United Arab Emirates, Jordan       March 9, 2016
# 6127                                      United States   November 20, 2019
# 6128                                      United States    November 1, 2019
# 6129                                      United States    January 11, 2020
# 6130                                              India       March 2, 2019
#
#       release_year rating duration  \
# 0             2020  PG-13   90 min
# 1             2021     PG   91 min
# 2             1993  TV-MA  125 min
# 3             2021  PG-13  104 min
# 4             2021  TV-MA  127 min
# ...            ...    ...      ...
# 6126          2015  TV-MA   96 min
# 6127          2007      R  158 min
# 6128          2009      R   88 min
# 6129          2006     PG   88 min
# 6130          2015  TV-14  111 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 1                             Children & Family Movies
# 2     Dramas, Independent Movies, International Movies
# 3                                     Comedies, Dramas
# 4                         Dramas, International Movies
# ...                                                ...
# 6126           Dramas, International Movies, Thrillers
# 6127                    Cult Movies, Dramas, Thrillers
# 6128                           Comedies, Horror Movies
# 6129                Children & Family Movies, Comedies
# 6130    Dramas, International Movies, Music & Musicals
#
#                                             description plataforma
# 0     As her father nears the end of his life, filmm...    netflix
# 1     Equestria's divided. But a bright-eyed hero be...    netflix
# 2     On a photo shoot in Ghana, an American model s...    netflix
# 3     A woman adjusting to life after a loss contend...    netflix
# 4     After most of her family is murdered in a terr...    netflix
# ...                                                 ...        ...
# 6126  Recovering alcoholic Talal wakes up inside a s...    netflix
# 6127  A political cartoonist, a crime reporter and a...    netflix
# 6128  Looking to survive in a world taken over by zo...    netflix
# 6129  Dragged from civilian life, a former superhero...    netflix
# 6130  A scrappy but poor boy worms his way into a ty...    netflix
#
# [6131 rows x 13 columns]

# %%
# Se repite la operación con todos los datasets:
#Se importa el dataset
hulu=pd.read_csv(r'hulu_titles.csv')
hulu
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                    Silent Night      NaN   NaN
# 2         s3    Movie                    The Marksman      NaN   NaN
# 3         s4    Movie                            Gaia      NaN   NaN
# 4         s5    Movie                        Settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069   s3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070   s3071  TV Show                       The Fades      NaN   NaN
# 3071   s3072  TV Show               The Twilight Zone      NaN   NaN
# 3072   s3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# 0                NaN  October 24, 2021          2021  TV-MA        NaN
# 1                NaN  October 23, 2021          2020    NaN     94 min
# 2                NaN  October 23, 2021          2021  PG-13    108 min
# 3                NaN  October 22, 2021          2021      R     97 min
# 4                NaN  October 22, 2021          2021    NaN    104 min
# ...              ...               ...           ...    ...        ...
# 3068   United States               NaN          1966  TV-PG  3 Seasons
# 3069   United States               NaN          1997  TV-PG  7 Seasons
# 3070  United Kingdom               NaN          2011  TV-14   1 Season
# 3071   United States               NaN          1959  TV-PG  5 Seasons
# 3072           Japan               NaN          2009  TV-14   1 Season
#
#                                    listed_in  \
# 0                           Comedy, Stand Up
# 1                     Crime, Drama, Thriller
# 2                           Action, Thriller
# 3                                     Horror
# 4                  Science Fiction, Thriller
# ...                                      ...
# 3068             Action, Adventure, Classics
# 3069      Action, Adventure, Science Fiction
# 3070  Horror, International, Science Fiction
# 3071     Classics, Science Fiction, Thriller
# 3072             Anime, Drama, International
#
#                                             description
# 0     ​Comedian Ricky Velez bares it all with his ho...
# 1     Mark, a low end South London hitman recently r...
# 2     A hardened Arizona rancher tries to protect an...
# 3     A forest ranger and two survivalists with a cu...
# 4     Mankind's earliest settlers on the Martian fro...
# ...                                                 ...
# 3068  The 23rd century adventures of Captain James T...
# 3069  Catapulted into the distant sector of the gala...
# 3070  Seventeen-year-old Paul is haunted by apocalyp...
# 3071  Rod Serling's seminal anthology series focused...
# 3072  The devastation is unleashed in the span of se...
#
# [3073 rows x 12 columns]

# %%
# Se crea un nuevo dataframe que sólo contenga películas
hulu_peli = hulu[hulu['type'] == "Movie"]
hulu_peli.shape # Se verifica la cantidad de filas
# Out:
# (1484, 12)

# %%
# Se guarda el dataframe en archivo CSV
hulu_peli.to_csv(r'C:\\Users\\Usuario\\Desktop\\data science\\GRUPO 9 FINAL\hulu_peli.csv', index=False)

# %%
hulu_peli = pd.read_csv(r'hulu_peli.csv')
hulu_peli
# Out:
#      show_id   type                                      title director  cast  \
# 0         s1  Movie             Ricky Velez: Here's Everything      NaN   NaN
# 1         s2  Movie                               Silent Night      NaN   NaN
# 2         s3  Movie                               The Marksman      NaN   NaN
# 3         s4  Movie                                       Gaia      NaN   NaN
# 4         s5  Movie                                   Settlers      NaN   NaN
# ...      ...    ...                                        ...      ...   ...
# 1479   s2956  Movie                                 Getting On      NaN   NaN
# 1480   s2959  Movie                         (Sub) Ninja Scroll      NaN   NaN
# 1481   s2960  Movie                      Packed to the Rafters      NaN   NaN
# 1482   s2983  Movie  (Sub) Legend of Heroes: Trails in the Sky      NaN   NaN
# 1483   s2994  Movie             Amy Winehouse: A Final Goodbye      NaN   NaN
#
#              country         date_added  release_year     rating duration  \
# 0                NaN   October 24, 2021          2021      TV-MA      NaN
# 1                NaN   October 23, 2021          2020        NaN   94 min
# 2                NaN   October 23, 2021          2021      PG-13  108 min
# 3                NaN   October 22, 2021          2021          R   97 min
# 4                NaN   October 22, 2021          2021        NaN  104 min
# ...              ...                ...           ...        ...      ...
# 1479  United Kingdom    January 7, 2014          2009  3 Seasons      NaN
# 1480           Japan  December 15, 2013          1993     93 min      NaN
# 1481       Australia   December 3, 2013          2008  6 Seasons      NaN
# 1482             NaN    August 31, 2013          2011      PG-13   84 min
# 1483  United Kingdom  December 13, 2012          2011     71 min      NaN
#
#                                   listed_in  \
# 0                          Comedy, Stand Up
# 1                    Crime, Drama, Thriller
# 2                          Action, Thriller
# 3                                    Horror
# 4                 Science Fiction, Thriller
# ...                                     ...
# 1479          Comedy, International, Sitcom
# 1480     Action, Adult Animation, Adventure
# 1481           Comedy, Drama, International
# 1482  Anime, International, Science Fiction
# 1483                   Documentaries, Music
#
#                                             description
# 0     ​Comedian Ricky Velez bares it all with his ho...
# 1     Mark, a low end South London hitman recently r...
# 2     A hardened Arizona rancher tries to protect an...
# 3     A forest ranger and two survivalists with a cu...
# 4     Mankind's earliest settlers on the Martian fro...
# ...                                                 ...
# 1479  Care for the elderly is the least glamorous ar...
# 1480  When Jubei saves a young ninja woman from the ...
# 1481  Packed to the Rafters is an Australian family-...
# 1482  Ten years ago, an invasion by the Erebonians a...
# 1483  A Final Goodbye is an intimate look into the l...
#
# [1484 rows x 12 columns]

# %% [markdown]
# Del análisis del data frame: hulu_peli, se concluye que se lo excluirá del análisis, debido a que no es una plataforma de uso en Argentina.

# %%
#Se importa un nuevo dataset
disney=pd.read_csv(r'disney_plus_titles.csv')
disney
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# 1                           John Cherry
# 2                          Karen Disher
# 3                       Hamish Hamilton
# 4                                   NaN
# ...                                 ...
# 1445                         Gavin Hood
# 1446                         Shawn Levy
# 1447                    Dexter Fletcher
# 1448                    Gurinder Chadha
# 1449                        Mark Waring
#
#                                                    cast  \
# 0     Chris Diamantopoulos, Tony Anselmo, Tress MacN...
# 1              Jim Varney, Noelle Parker, Douglas Seale
# 2     Raymond Albert Romano, John Leguizamo, Denis L...
# 3     Darren Criss, Adam Lambert, Derek Hough, Alexa...
# 4     John Lennon, Paul McCartney, George Harrison, ...
# ...                                                 ...
# 1445  Hugh Jackman, Liev Schreiber, Danny Huston, wi...
# 1446  Ben Stiller, Amy Adams, Owen Wilson, Hank Azar...
# 1447  Tom Costello, Jo Hartley, Keith Allen, Dickon ...
# 1448  Parminder Nagra, Keira Knightley, Jonathan Rhy...
# 1449                                      Charlie Tahan
#
#                                      country          date_added  \
# 0                                        NaN   November 26, 2021
# 1                                        NaN   November 26, 2021
# 2                              United States   November 26, 2021
# 3                                        NaN   November 26, 2021
# 4                                        NaN   November 25, 2021
# ...                                      ...                 ...
# 1445           United States, United Kingdom        June 4, 2021
# 1446                   United States, Canada       April 2, 2021
# 1447  United Kingdom, Germany, United States   December 18, 2020
# 1448  United Kingdom, Germany, United States  September 18, 2020
# 1449                           United States       April 1, 2020
#
#       release_year rating  duration  \
# 0             2016   TV-G    23 min
# 1             1988     PG    91 min
# 2             2011   TV-G    23 min
# 3             2021  TV-PG    41 min
# 4             2021    NaN  1 Season
# ...            ...    ...       ...
# 1445          2009  PG-13   108 min
# 1446          2009     PG   106 min
# 1447          2016  PG-13   107 min
# 1448          2003  PG-13   112 min
# 1449          2012   TV-G     2 min
#
#                                           listed_in  \
# 0                                 Animation, Family
# 1                                            Comedy
# 2                         Animation, Comedy, Family
# 3                                           Musical
# 4                     Docuseries, Historical, Music
# ...                                             ...
# 1445      Action-Adventure, Family, Science Fiction
# 1446               Action-Adventure, Comedy, Family
# 1447                    Biographical, Comedy, Drama
# 1448                   Buddy, Comedy, Coming of Age
# 1449  Action-Adventure, Animals & Nature, Animation
#
#                                             description
# 0      Join Mickey and the gang as they duck the halls!
# 1     Santa Claus passes his magic bag to a new St. ...
# 2             Sid the Sloth is on Santa's naughty list.
# 3                  This is real life, not just fantasy!
# 4     A three-part documentary from Peter Jackson ca...
# ...                                                 ...
# 1445  Wolverine unites with legendary X-Men to fight...
# 1446  Larry Daley returns to rescue some old friends...
# 1447  True story of Eddie Edwards, a British ski-jum...
# 1448  Despite the wishes of their traditional famili...
# 1449         View one of Sparky's favorite home movies.
#
# [1450 rows x 12 columns]

# %%
# Se crea un nuevo dataframe filtrando por el valor de la columna type
disney_peli = disney[disney['type'] == "Movie"]
disney_peli.shape ## chequeo la cantidad de filas
# Out:
# (1052, 12)

# %%
# Se guarda el dataframe en archivo CSV
disney_peli.to_csv(r'C:\\Users\\Usuario\\Desktop\\data science\\GRUPO 9 FINAL\disney_peli.csv', index=False)

# %%
#Se importa un nuevo dataset
disney_peli=pd.read_csv(r'disney_plus_titles.csv')
disney_peli
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# 1                           John Cherry
# 2                          Karen Disher
# 3                       Hamish Hamilton
# 4                                   NaN
# ...                                 ...
# 1445                         Gavin Hood
# 1446                         Shawn Levy
# 1447                    Dexter Fletcher
# 1448                    Gurinder Chadha
# 1449                        Mark Waring
#
#                                                    cast  \
# 0     Chris Diamantopoulos, Tony Anselmo, Tress MacN...
# 1              Jim Varney, Noelle Parker, Douglas Seale
# 2     Raymond Albert Romano, John Leguizamo, Denis L...
# 3     Darren Criss, Adam Lambert, Derek Hough, Alexa...
# 4     John Lennon, Paul McCartney, George Harrison, ...
# ...                                                 ...
# 1445  Hugh Jackman, Liev Schreiber, Danny Huston, wi...
# 1446  Ben Stiller, Amy Adams, Owen Wilson, Hank Azar...
# 1447  Tom Costello, Jo Hartley, Keith Allen, Dickon ...
# 1448  Parminder Nagra, Keira Knightley, Jonathan Rhy...
# 1449                                      Charlie Tahan
#
#                                      country          date_added  \
# 0                                        NaN   November 26, 2021
# 1                                        NaN   November 26, 2021
# 2                              United States   November 26, 2021
# 3                                        NaN   November 26, 2021
# 4                                        NaN   November 25, 2021
# ...                                      ...                 ...
# 1445           United States, United Kingdom        June 4, 2021
# 1446                   United States, Canada       April 2, 2021
# 1447  United Kingdom, Germany, United States   December 18, 2020
# 1448  United Kingdom, Germany, United States  September 18, 2020
# 1449                           United States       April 1, 2020
#
#       release_year rating  duration  \
# 0             2016   TV-G    23 min
# 1             1988     PG    91 min
# 2             2011   TV-G    23 min
# 3             2021  TV-PG    41 min
# 4             2021    NaN  1 Season
# ...            ...    ...       ...
# 1445          2009  PG-13   108 min
# 1446          2009     PG   106 min
# 1447          2016  PG-13   107 min
# 1448          2003  PG-13   112 min
# 1449          2012   TV-G     2 min
#
#                                           listed_in  \
# 0                                 Animation, Family
# 1                                            Comedy
# 2                         Animation, Comedy, Family
# 3                                           Musical
# 4                     Docuseries, Historical, Music
# ...                                             ...
# 1445      Action-Adventure, Family, Science Fiction
# 1446               Action-Adventure, Comedy, Family
# 1447                    Biographical, Comedy, Drama
# 1448                   Buddy, Comedy, Coming of Age
# 1449  Action-Adventure, Animals & Nature, Animation
#
#                                             description
# 0      Join Mickey and the gang as they duck the halls!
# 1     Santa Claus passes his magic bag to a new St. ...
# 2             Sid the Sloth is on Santa's naughty list.
# 3                  This is real life, not just fantasy!
# 4     A three-part documentary from Peter Jackson ca...
# ...                                                 ...
# 1445  Wolverine unites with legendary X-Men to fight...
# 1446  Larry Daley returns to rescue some old friends...
# 1447  True story of Eddie Edwards, a British ski-jum...
# 1448  Despite the wishes of their traditional famili...
# 1449         View one of Sparky's favorite home movies.
#
# [1450 rows x 12 columns]

# %%
# Se crea la columna plataforma 
# Se crea la columna plataforma 
disney_peli['plataforma']='disney'
disney_peli
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# 1                           John Cherry
# 2                          Karen Disher
# 3                       Hamish Hamilton
# 4                                   NaN
# ...                                 ...
# 1445                         Gavin Hood
# 1446                         Shawn Levy
# 1447                    Dexter Fletcher
# 1448                    Gurinder Chadha
# 1449                        Mark Waring
#
#                                                    cast  \
# 0     Chris Diamantopoulos, Tony Anselmo, Tress MacN...
# 1              Jim Varney, Noelle Parker, Douglas Seale
# 2     Raymond Albert Romano, John Leguizamo, Denis L...
# 3     Darren Criss, Adam Lambert, Derek Hough, Alexa...
# 4     John Lennon, Paul McCartney, George Harrison, ...
# ...                                                 ...
# 1445  Hugh Jackman, Liev Schreiber, Danny Huston, wi...
# 1446  Ben Stiller, Amy Adams, Owen Wilson, Hank Azar...
# 1447  Tom Costello, Jo Hartley, Keith Allen, Dickon ...
# 1448  Parminder Nagra, Keira Knightley, Jonathan Rhy...
# 1449                                      Charlie Tahan
#
#                                      country          date_added  \
# 0                                        NaN   November 26, 2021
# 1                                        NaN   November 26, 2021
# 2                              United States   November 26, 2021
# 3                                        NaN   November 26, 2021
# 4                                        NaN   November 25, 2021
# ...                                      ...                 ...
# 1445           United States, United Kingdom        June 4, 2021
# 1446                   United States, Canada       April 2, 2021
# 1447  United Kingdom, Germany, United States   December 18, 2020
# 1448  United Kingdom, Germany, United States  September 18, 2020
# 1449                           United States       April 1, 2020
#
#       release_year rating  duration  \
# 0             2016   TV-G    23 min
# 1             1988     PG    91 min
# 2             2011   TV-G    23 min
# 3             2021  TV-PG    41 min
# 4             2021    NaN  1 Season
# ...            ...    ...       ...
# 1445          2009  PG-13   108 min
# 1446          2009     PG   106 min
# 1447          2016  PG-13   107 min
# 1448          2003  PG-13   112 min
# 1449          2012   TV-G     2 min
#
#                                           listed_in  \
# 0                                 Animation, Family
# 1                                            Comedy
# 2                         Animation, Comedy, Family
# 3                                           Musical
# 4                     Docuseries, Historical, Music
# ...                                             ...
# 1445      Action-Adventure, Family, Science Fiction
# 1446               Action-Adventure, Comedy, Family
# 1447                    Biographical, Comedy, Drama
# 1448                   Buddy, Comedy, Coming of Age
# 1449  Action-Adventure, Animals & Nature, Animation
#
#                                             description plataforma
# 0      Join Mickey and the gang as they duck the halls!     disney
# 1     Santa Claus passes his magic bag to a new St. ...     disney
# 2             Sid the Sloth is on Santa's naughty list.     disney
# 3                  This is real life, not just fantasy!     disney
# 4     A three-part documentary from Peter Jackson ca...     disney
# ...                                                 ...        ...
# 1445  Wolverine unites with legendary X-Men to fight...     disney
# 1446  Larry Daley returns to rescue some old friends...     disney
# 1447  True story of Eddie Edwards, a British ski-jum...     disney
# 1448  Despite the wishes of their traditional famili...     disney
# 1449         View one of Sparky's favorite home movies.     disney
#
# [1450 rows x 13 columns]

# %%
amazon_peli
# Out:
#      show_id   type                 title  \
# 0         s1  Movie   The Grand Seduction
# 1         s2  Movie  Take Care Good Night
# 2         s3  Movie  Secrets of Deception
# 3         s4  Movie    Pink: Staying True
# 4         s5  Movie         Monster Maker
# ...      ...    ...                   ...
# 7809   s9661  Movie    The Man in the Hat
# 7810   s9663  Movie                 River
# 7811   s9664  Movie   Pride Of The Bowery
# 7812   s9666  Movie               Outpost
# 7813   s9668  Movie           Harry Brown
#
#                                  director  \
# 0                            Don McKellar
# 1                            Girish Joshi
# 2                             Josh Webber
# 3                          Sonia Anderson
# 4                            Giles Foster
# ...                                   ...
# 7809  John-Paul Davidson, Stephen Warbeck
# 7810                           Emily Skye
# 7811                      Joseph H. Lewis
# 7812                         Steve Barker
# 7813                        Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# ...                                                 ...             ...
# 7809             Ciaran Hinds, Stephen Dillane, Maïwenn             NaN
# 7810  Mary Cameron Rogers, Alexandra Rose, Rob Marsh...             NaN
# 7811                           Leo Gorcey, Bobby Jordan             NaN
# 7812  Ray Stevenson, Julian Wadham, Richard Brake, M...             NaN
# 7813  Michael Caine, Emily Mortimer, Joseph Gilgun, ...             NaN
#
#           date_added  release_year rating  duration  \
# 0     March 30, 2021          2014    NaN       113
# 1     March 30, 2021          2018    13+       110
# 2     March 30, 2021          2017    NaN        74
# 3     March 30, 2021          2014    NaN        69
# 4     March 30, 2021          1989    NaN        45
# ...              ...           ...    ...       ...
# 7809             NaN          2021    13+        96
# 7810             NaN          2021    16+        93
# 7811             NaN          1940     7+        60
# 7812             NaN          2008      R        90
# 7813             NaN          2010      R       103
#
#                              listed_in  \
# 0                        Comedy, Drama
# 1                 Drama, International
# 2              Action, Drama, Suspense
# 3                          Documentary
# 4                       Drama, Fantasy
# ...                                ...
# 7809                            Comedy
# 7810  Drama, Science Fiction, Suspense
# 7811                            Comedy
# 7812                            Action
# 7813           Action, Drama, Suspense
#
#                                             description
# 0     A small fishing village must procure a local d...
# 1     A Metro Family decides to fight a Cyber Crimin...
# 2     After a man discovers his wife is cheating on ...
# 3     Pink breaks the mold once again, bringing her ...
# 4     Teenage Matt Banting wants to work with a famo...
# ...                                                 ...
# 7809  The Man in the Hat journeys through France in ...
# 7810  River is a grounded Sci-Fi mystery Thriller, t...
# 7811  New York City street principles get an East Si...
# 7812  In war-torn Eastern Europe, a world-weary grou...
# 7813  Harry Brown, starring two-time Academy Award w...
#
# [7814 rows x 12 columns]

# %%
# Se crea la columna plataforma 
# Se crea la columna plataforma 
amazon_peli['plataforma']='amazon'
amazon_peli
# Out:
#      show_id   type                 title  \
# 0         s1  Movie   The Grand Seduction
# 1         s2  Movie  Take Care Good Night
# 2         s3  Movie  Secrets of Deception
# 3         s4  Movie    Pink: Staying True
# 4         s5  Movie         Monster Maker
# ...      ...    ...                   ...
# 7809   s9661  Movie    The Man in the Hat
# 7810   s9663  Movie                 River
# 7811   s9664  Movie   Pride Of The Bowery
# 7812   s9666  Movie               Outpost
# 7813   s9668  Movie           Harry Brown
#
#                                  director  \
# 0                            Don McKellar
# 1                            Girish Joshi
# 2                             Josh Webber
# 3                          Sonia Anderson
# 4                            Giles Foster
# ...                                   ...
# 7809  John-Paul Davidson, Stephen Warbeck
# 7810                           Emily Skye
# 7811                      Joseph H. Lewis
# 7812                         Steve Barker
# 7813                        Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# ...                                                 ...             ...
# 7809             Ciaran Hinds, Stephen Dillane, Maïwenn             NaN
# 7810  Mary Cameron Rogers, Alexandra Rose, Rob Marsh...             NaN
# 7811                           Leo Gorcey, Bobby Jordan             NaN
# 7812  Ray Stevenson, Julian Wadham, Richard Brake, M...             NaN
# 7813  Michael Caine, Emily Mortimer, Joseph Gilgun, ...             NaN
#
#           date_added  release_year rating  duration  \
# 0     March 30, 2021          2014    NaN       113
# 1     March 30, 2021          2018    13+       110
# 2     March 30, 2021          2017    NaN        74
# 3     March 30, 2021          2014    NaN        69
# 4     March 30, 2021          1989    NaN        45
# ...              ...           ...    ...       ...
# 7809             NaN          2021    13+        96
# 7810             NaN          2021    16+        93
# 7811             NaN          1940     7+        60
# 7812             NaN          2008      R        90
# 7813             NaN          2010      R       103
#
#                              listed_in  \
# 0                        Comedy, Drama
# 1                 Drama, International
# 2              Action, Drama, Suspense
# 3                          Documentary
# 4                       Drama, Fantasy
# ...                                ...
# 7809                            Comedy
# 7810  Drama, Science Fiction, Suspense
# 7811                            Comedy
# 7812                            Action
# 7813           Action, Drama, Suspense
#
#                                             description plataforma
# 0     A small fishing village must procure a local d...     amazon
# 1     A Metro Family decides to fight a Cyber Crimin...     amazon
# 2     After a man discovers his wife is cheating on ...     amazon
# 3     Pink breaks the mold once again, bringing her ...     amazon
# 4     Teenage Matt Banting wants to work with a famo...     amazon
# ...                                                 ...        ...
# 7809  The Man in the Hat journeys through France in ...     amazon
# 7810  River is a grounded Sci-Fi mystery Thriller, t...     amazon
# 7811  New York City street principles get an East Si...     amazon
# 7812  In war-torn Eastern Europe, a world-weary grou...     amazon
# 7813  Harry Brown, starring two-time Academy Award w...     amazon
#
# [7814 rows x 13 columns]

# %%
# finalmente se concatenan los dataframes
peliculas=pd.concat([amazon_peli,netflix_peli,disney_peli],axis=0,join='outer')
print (peliculas)
# Out:
#      show_id   type                                           title  \
# 0         s1  Movie                             The Grand Seduction
# 1         s2  Movie                            Take Care Good Night
# 2         s3  Movie                            Secrets of Deception
# 3         s4  Movie                              Pink: Staying True
# 4         s5  Movie                                   Monster Maker
# ...      ...    ...                                             ...
# 1445   s1446  Movie                        X-Men Origins: Wolverine
# 1446   s1447  Movie  Night at the Museum: Battle of the Smithsonian
# 1447   s1448  Movie                                 Eddie the Eagle
# 1448   s1449  Movie                            Bend It Like Beckham
# 1449   s1450  Movie           Captain Sparky vs. The Flying Saucers
#
#              director                                               cast  \
# 0        Don McKellar     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# 1        Girish Joshi   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar
# 2         Josh Webber  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...
# 3      Sonia Anderson  Interviews with: Pink, Adele, Beyoncé, Britney...
# 4        Giles Foster  Harry Dean Stanton, Kieran O'Brien, George Cos...
# ...               ...                                                ...
# 1445       Gavin Hood  Hugh Jackman, Liev Schreiber, Danny Huston, wi...
# 1446       Shawn Levy  Ben Stiller, Amy Adams, Owen Wilson, Hank Azar...
# 1447  Dexter Fletcher  Tom Costello, Jo Hartley, Keith Allen, Dickon ...
# 1448  Gurinder Chadha  Parminder Nagra, Keira Knightley, Jonathan Rhy...
# 1449      Mark Waring                                      Charlie Tahan
#
#                                      country          date_added  \
# 0                                     Canada      March 30, 2021
# 1                                      India      March 30, 2021
# 2                              United States      March 30, 2021
# 3                              United States      March 30, 2021
# 4                             United Kingdom      March 30, 2021
# ...                                      ...                 ...
# 1445           United States, United Kingdom        June 4, 2021
# 1446                   United States, Canada       April 2, 2021
# 1447  United Kingdom, Germany, United States   December 18, 2020
# 1448  United Kingdom, Germany, United States  September 18, 2020
# 1449                           United States       April 1, 2020
#
#       release_year rating duration  \
# 0             2014    NaN      113
# 1             2018    13+      110
# 2             2017    NaN       74
# 3             2014    NaN       69
# 4             1989    NaN       45
# ...            ...    ...      ...
# 1445          2009  PG-13  108 min
# 1446          2009     PG  106 min
# 1447          2016  PG-13  107 min
# 1448          2003  PG-13  112 min
# 1449          2012   TV-G    2 min
#
#                                           listed_in  \
# 0                                     Comedy, Drama
# 1                              Drama, International
# 2                           Action, Drama, Suspense
# 3                                       Documentary
# 4                                    Drama, Fantasy
# ...                                             ...
# 1445      Action-Adventure, Family, Science Fiction
# 1446               Action-Adventure, Comedy, Family
# 1447                    Biographical, Comedy, Drama
# 1448                   Buddy, Comedy, Coming of Age
# 1449  Action-Adventure, Animals & Nature, Animation
#
#                                             description plataforma
# 0     A small fishing village must procure a local d...     amazon
# 1     A Metro Family decides to fight a Cyber Crimin...     amazon
# 2     After a man discovers his wife is cheating on ...     amazon
# 3     Pink breaks the mold once again, bringing her ...     amazon
# 4     Teenage Matt Banting wants to work with a famo...     amazon
# ...                                                 ...        ...
# 1445  Wolverine unites with legendary X-Men to fight...     disney
# 1446  Larry Daley returns to rescue some old friends...     disney
# 1447  True story of Eddie Edwards, a British ski-jum...     disney
# 1448  Despite the wishes of their traditional famili...     disney
# 1449         View one of Sparky's favorite home movies.     disney
#
# [15395 rows x 13 columns]

# %%
peliculas
# Out:
#      show_id   type                                           title  \
# 0         s1  Movie                             The Grand Seduction
# 1         s2  Movie                            Take Care Good Night
# 2         s3  Movie                            Secrets of Deception
# 3         s4  Movie                              Pink: Staying True
# 4         s5  Movie                                   Monster Maker
# ...      ...    ...                                             ...
# 1445   s1446  Movie                        X-Men Origins: Wolverine
# 1446   s1447  Movie  Night at the Museum: Battle of the Smithsonian
# 1447   s1448  Movie                                 Eddie the Eagle
# 1448   s1449  Movie                            Bend It Like Beckham
# 1449   s1450  Movie           Captain Sparky vs. The Flying Saucers
#
#              director                                               cast  \
# 0        Don McKellar     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# 1        Girish Joshi   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar
# 2         Josh Webber  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...
# 3      Sonia Anderson  Interviews with: Pink, Adele, Beyoncé, Britney...
# 4        Giles Foster  Harry Dean Stanton, Kieran O'Brien, George Cos...
# ...               ...                                                ...
# 1445       Gavin Hood  Hugh Jackman, Liev Schreiber, Danny Huston, wi...
# 1446       Shawn Levy  Ben Stiller, Amy Adams, Owen Wilson, Hank Azar...
# 1447  Dexter Fletcher  Tom Costello, Jo Hartley, Keith Allen, Dickon ...
# 1448  Gurinder Chadha  Parminder Nagra, Keira Knightley, Jonathan Rhy...
# 1449      Mark Waring                                      Charlie Tahan
#
#                                      country          date_added  \
# 0                                     Canada      March 30, 2021
# 1                                      India      March 30, 2021
# 2                              United States      March 30, 2021
# 3                              United States      March 30, 2021
# 4                             United Kingdom      March 30, 2021
# ...                                      ...                 ...
# 1445           United States, United Kingdom        June 4, 2021
# 1446                   United States, Canada       April 2, 2021
# 1447  United Kingdom, Germany, United States   December 18, 2020
# 1448  United Kingdom, Germany, United States  September 18, 2020
# 1449                           United States       April 1, 2020
#
#       release_year rating duration  \
# 0             2014    NaN      113
# 1             2018    13+      110
# 2             2017    NaN       74
# 3             2014    NaN       69
# 4             1989    NaN       45
# ...            ...    ...      ...
# 1445          2009  PG-13  108 min
# 1446          2009     PG  106 min
# 1447          2016  PG-13  107 min
# 1448          2003  PG-13  112 min
# 1449          2012   TV-G    2 min
#
#                                           listed_in  \
# 0                                     Comedy, Drama
# 1                              Drama, International
# 2                           Action, Drama, Suspense
# 3                                       Documentary
# 4                                    Drama, Fantasy
# ...                                             ...
# 1445      Action-Adventure, Family, Science Fiction
# 1446               Action-Adventure, Comedy, Family
# 1447                    Biographical, Comedy, Drama
# 1448                   Buddy, Comedy, Coming of Age
# 1449  Action-Adventure, Animals & Nature, Animation
#
#                                             description plataforma
# 0     A small fishing village must procure a local d...     amazon
# 1     A Metro Family decides to fight a Cyber Crimin...     amazon
# 2     After a man discovers his wife is cheating on ...     amazon
# 3     Pink breaks the mold once again, bringing her ...     amazon
# 4     Teenage Matt Banting wants to work with a famo...     amazon
# ...                                                 ...        ...
# 1445  Wolverine unites with legendary X-Men to fight...     disney
# 1446  Larry Daley returns to rescue some old friends...     disney
# 1447  True story of Eddie Edwards, a British ski-jum...     disney
# 1448  Despite the wishes of their traditional famili...     disney
# 1449         View one of Sparky's favorite home movies.     disney
#
# [15395 rows x 13 columns]

# %%
# Se alamacena el dataframe final:
peliculas.to_csv(r'C:\\Users\\Usuario\\Desktop\\data science\\GRUPO 9 FINAL\peliculas.csv', index=False)

# %%
peliculas
# Out:
#      show_id   type                                           title  \
# 0         s1  Movie                             The Grand Seduction
# 1         s2  Movie                            Take Care Good Night
# 2         s3  Movie                            Secrets of Deception
# 3         s4  Movie                              Pink: Staying True
# 4         s5  Movie                                   Monster Maker
# ...      ...    ...                                             ...
# 1445   s1446  Movie                        X-Men Origins: Wolverine
# 1446   s1447  Movie  Night at the Museum: Battle of the Smithsonian
# 1447   s1448  Movie                                 Eddie the Eagle
# 1448   s1449  Movie                            Bend It Like Beckham
# 1449   s1450  Movie           Captain Sparky vs. The Flying Saucers
#
#              director                                               cast  \
# 0        Don McKellar     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# 1        Girish Joshi   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar
# 2         Josh Webber  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...
# 3      Sonia Anderson  Interviews with: Pink, Adele, Beyoncé, Britney...
# 4        Giles Foster  Harry Dean Stanton, Kieran O'Brien, George Cos...
# ...               ...                                                ...
# 1445       Gavin Hood  Hugh Jackman, Liev Schreiber, Danny Huston, wi...
# 1446       Shawn Levy  Ben Stiller, Amy Adams, Owen Wilson, Hank Azar...
# 1447  Dexter Fletcher  Tom Costello, Jo Hartley, Keith Allen, Dickon ...
# 1448  Gurinder Chadha  Parminder Nagra, Keira Knightley, Jonathan Rhy...
# 1449      Mark Waring                                      Charlie Tahan
#
#                                      country          date_added  \
# 0                                     Canada      March 30, 2021
# 1                                      India      March 30, 2021
# 2                              United States      March 30, 2021
# 3                              United States      March 30, 2021
# 4                             United Kingdom      March 30, 2021
# ...                                      ...                 ...
# 1445           United States, United Kingdom        June 4, 2021
# 1446                   United States, Canada       April 2, 2021
# 1447  United Kingdom, Germany, United States   December 18, 2020
# 1448  United Kingdom, Germany, United States  September 18, 2020
# 1449                           United States       April 1, 2020
#
#       release_year rating duration  \
# 0             2014    NaN      113
# 1             2018    13+      110
# 2             2017    NaN       74
# 3             2014    NaN       69
# 4             1989    NaN       45
# ...            ...    ...      ...
# 1445          2009  PG-13  108 min
# 1446          2009     PG  106 min
# 1447          2016  PG-13  107 min
# 1448          2003  PG-13  112 min
# 1449          2012   TV-G    2 min
#
#                                           listed_in  \
# 0                                     Comedy, Drama
# 1                              Drama, International
# 2                           Action, Drama, Suspense
# 3                                       Documentary
# 4                                    Drama, Fantasy
# ...                                             ...
# 1445      Action-Adventure, Family, Science Fiction
# 1446               Action-Adventure, Comedy, Family
# 1447                    Biographical, Comedy, Drama
# 1448                   Buddy, Comedy, Coming of Age
# 1449  Action-Adventure, Animals & Nature, Animation
#
#                                             description plataforma
# 0     A small fishing village must procure a local d...     amazon
# 1     A Metro Family decides to fight a Cyber Crimin...     amazon
# 2     After a man discovers his wife is cheating on ...     amazon
# 3     Pink breaks the mold once again, bringing her ...     amazon
# 4     Teenage Matt Banting wants to work with a famo...     amazon
# ...                                                 ...        ...
# 1445  Wolverine unites with legendary X-Men to fight...     disney
# 1446  Larry Daley returns to rescue some old friends...     disney
# 1447  True story of Eddie Edwards, a British ski-jum...     disney
# 1448  Despite the wishes of their traditional famili...     disney
# 1449         View one of Sparky's favorite home movies.     disney
#
# [15395 rows x 13 columns]
